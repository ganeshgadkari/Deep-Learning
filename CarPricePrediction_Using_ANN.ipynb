# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
data = pd.read_csv("https://raw.githubusercontent.com/ingledarshan/GreatLearning/main/usedcars.csv")
data.shape
# Out:
# (150, 6)

# %%
data.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413    Gray         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2011    SE  17500     8367   White         AUTO

# %%
# Droping irrelevant features

data=data[["year", "price", "mileage"]]
data.head()
# Out:
#    year  price  mileage
# 0  2011  21992     7413
# 1  2011  20995    10926
# 2  2011  19995     7351
# 3  2011  17809    11613
# 4  2011  17500     8367

# %%
# Train test split with 70-30 & random state=42

from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(data[["year", "mileage"]],data["price"], test_size=0.30, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((105, 2), (45, 2), (105,), (45,))

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
# Neural Network 1
"""
model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=2)),
model.add(tf.keras.layers.Dense(1))
"""

# Neural Network 2
model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=2))
model.add(tf.keras.layers.Dense(64, activation="gelu"))
model.add(tf.keras.layers.Dense(128, activation="gelu"))
model.add(tf.keras.layers.Dense(256, activation="gelu"))
model.add(tf.keras.layers.Dense(512, activation="gelu"))
model.add(tf.keras.layers.Dense(1024, activation="gelu"))
model.add(tf.keras.layers.Dense(2048, activation="gelu"))
model.add(tf.keras.layers.Dense(1))

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %%
from re import VERBOSE
model.fit(X_train,y_train, epochs=260, verbose=True, validation_split=0.10)
# Out:
# Epoch 1/260
# 3/3 [==============================] - 2s 95ms/step - loss: 122849560.0000 - val_loss: 86100688.0000
# Epoch 2/260
# 3/3 [==============================] - 0s 15ms/step - loss: 91042928.0000 - val_loss: 80043984.0000
# Epoch 3/260
# 3/3 [==============================] - 0s 15ms/step - loss: 80711408.0000 - val_loss: 75443944.0000
# Epoch 4/260
# 3/3 [==============================] - 0s 15ms/step - loss: 74980480.0000 - val_loss: 73397640.0000
# Epoch 5/260
# 3/3 [==============================] - 0s 15ms/step - loss: 75087816.0000 - val_loss: 71375312.0000
# Epoch 6/260
# 3/3 [==============================] - 0s 15ms/step - loss: 72689656.0000 - val_loss: 68819856.0000
# Epoch 7/260
# 3/3 [==============================] - 0s 15ms/step - loss: 69757688.0000 - val_loss: 66287628.0000
# Epoch 8/260
# 3/3 [==============================] - 0s 15ms/step - loss: 68422920.0000 - val_loss: 60536552.0000
# Epoch 9/260
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
y_pred[0:5]
# Out:
# array([[14510.446],
#        [17162.781],
#        [ 9446.021],
#        [13787.695],
#        [10213.439]], dtype=float32)

# %%
y_test[0:5]
# Out:
# 73     13663
# 18     15992
# 118    10815
# 78     13383
# 76     13425
# Name: price, dtype: int64

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 4848793.747114552

# %%
# RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 2201.9976719139718

# %%
r2_score(y_test, y_pred)
# Out:
# 0.515664167672414
